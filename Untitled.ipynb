# %%
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta

# %%
def find_duplicate_trades(df):
    # Group the dataframe by Ticker and Trade Date
    grouped = df.groupby(['Ticker', 'Trade Date'])

    # Filter the groups to only include those with more than one row
    duplicates = grouped.filter(lambda x: len(x) > 1)

    # Get the unique Ticker and Trade Date combinations for the duplicate trades
    unique_duplicates = duplicates[['Ticker', 'Trade Date']].drop_duplicates()

    # Initialize an empty dataframe to store the results
    results = pd.DataFrame(columns=['Ticker', 'Trade Date', 'Trade Type', 'Total Volume', 'No. of Insiders'])

    # Iterate through the unique duplicates
    for i, row in unique_duplicates.iterrows():
        ticker = row['Ticker']
        trade_date = row['Trade Date']

        # Filter the dataframe to only include trades for the current Ticker and Trade Date
        filtered_df = df[(df['Ticker'] == ticker) & (df['Trade Date'] == trade_date)]

        # Determine if the trades were buys or sells
        trade_types = filtered_df['Trade Type'].unique()
        if len(trade_types) > 1:
            trade_type = 'Both'
        else:
            trade_type = trade_types[0]

        # Calculate the total volume for the day
        total_volume = filtered_df['Qty'].sum()
        # Calculate the number of unique insiders who traded on this day
        no_of_insiders = filtered_df['Insider Name'].nunique()
        # Add the result to the dataframe
        results = results.append({'Ticker': ticker, 'Trade Date': trade_date, 'Trade Type': trade_type,
                                  'Total Volume': total_volume, 'No. of Insiders': no_of_insiders},
                                 ignore_index=True)

    return results[(results['Trade Type'] == "S - Sale") & (results['No. of Insiders'] > 2)]

# %%
def add_ticker_price(df):
    # Iterate through each row of the DataFrame
    for i, row in df.iterrows():
        # Get the Ticker and Trade Date for this row
        ticker = row['Ticker']
        print(f"{ticker=}")
        trade_date = row['Trade Date']

        # Fetch the historical data for the Ticker on the Trade Date
        ticker_data_past = yf.download(ticker, start=trade_date, end=get_today())
        ticker_data_now = get_current_price(ticker)

        # If there is no data for this Ticker on this Trade Date, skip this row
        if ticker_data_past.empty or ticker_data_now is None:
            df.loc[i, 'Traded Price'] = None
            df.loc[i, 'Actual Price'] = None
            continue

        # Get the closing price for this Ticker on this Trade Date
        closing_price_past = ticker_data_past.loc[trade_date]['Close']

        # Add the closing price to the DataFrame
        df.loc[i, 'Traded Price'] = closing_price_past
        df.loc[i, 'Actual Price'] = ticker_data_now
        df['Increase/Decrease Pct'] = (((df['Actual Price'] - df['Traded Price']) / df['Traded Price']) * 100).round(2)
    return df

# %%
def date_operation(date_str, num_days):
    new_date_obj = datetime.strptime(date_str, "%Y-%m-%d") + timedelta(days=num_days)
    return datetime.today().strftime("%Y-%m-%d") if new_date_obj > datetime.today() else new_date_obj.strftime("%Y-%m-%d")
def get_today():
    return datetime.today().strftime("%Y-%m-%d")
def get_current_price(symbol):
    ticker = yf.Ticker(symbol)
    todays_data = ticker.history(period='1d')
    if not todays_data.empty:
        return todays_data['Close'][0]
    else: 
        return None

# %%
url = "http://openinsider.com/screener?s=&o=&pl=&ph=&ll=&lh=&fd=730&fdr=&td=0&tdr=&fdlyl=&fdlyh=&daysago=&xs=1&vl=100&vh=&ocl=&och=&sic1=-1&sicl=&sich=&grp=0&nfl=&nfh=&nil=&nih=&nol=&noh=&v2l=&v2h=&oc2l=&oc2h=&sortcol=0&cnt=1000&page=2"

# %%
inside_trades = pd.read_html(url)[11]
inside_trades.columns = [c.replace('\xa0', ' ') for c in inside_trades.columns]

# %%
stocks_to_trade = find_duplicate_trades(inside_trades)
# Out:
# C:\Users\Curtis\AppData\Local\Temp\ipykernel_8376\896725339.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'Ticker': ticker, 'Trade Date': trade_date, 'Trade Type': trade_type
# 155   PTON  2023-02-21   S - Sale       -54530               3
# 158    MTH  2023-02-22   S - Sale       -68153               5

# %%
priced_df = add_ticker_price(stocks_to_trade)
# Out:
# ticker='PCOR'
# [*********************100%***********************]  1 of 1 completed
# ticker='LMT'
# [*********************100%***********************]  1 of 1 completed
# ticker='SKX'
# [*********************100%***********************]  1 of 1 completed
# ticker='ABT'
# [*********************100%***********************]  1 of 1 completed
# ticker='DASH'
# [*********************100%***********************]  1 of 1 completed
# ticker='FND'
# [*********************100%***********************]  1 of 1 completed
# ticker='IPG'
# [*********************100%***********************]  1 of 1 completed
# ticker='AEE'
# [*********************100%***********************]  1 of 1 completed
# ticker='BLKB'
# [*********************100%***********************]  1 of 1 completed
# ticker='MAXR'
# [*********************100%***********************]  1 of 1 completed
# ticker='MAXR'
# [*********************100%***********************]  1 of 1 completed
# ticker='SYF'
# [*********************100%***********************]  1 of 1 completed
# ticker='SGRY'
# [*********************100%***********************]  1 of 1 completed
# ticker='U'
# [*********************100%***********************]  1 of 1 completed
# ticker='IRTC'
# [*********************100%***********************]  1 of 1 completed
# ticker='WMT'
# [*********************100%***********************]  1 of 1 completed
# ticker='IRWD'
# [*********************100%***********************]  1 of 1 completed
# ticker='LGIH'
# [*********************100%***********************]  1 of 1 completed
# ticker='CLW'
# [*********************100%***********************]  1 of 1 completed
# ticker='AMR'
# [*********************100%***********************]  1 of 1 completed
# ticker='TRGP'
# [*********************100%***********************]  1 of 1 completed
# ticker='QURE'
# [*********************100%***********************]  1 of 1 completed
# ticker='MYRG'
# [*********************100%***********************]  1 of 1 completed
# ticker='TENB'
# [*********************100%***********************]  1 of 1 completed
# ticker='LPLA'
# [*********************100%***********************]  1 of 1 completed
# ticker='CI'
# [*********************100%***********************]  1 of 1 completed
# ticker='VRTX'
# [*********************100%***********************]  1 of 1 completed
# ticker='ADUS'
# [*********************100%***********************]  1 of 1 completed
# ticker='JOBY'
# [*********************100%***********************]  1 of 1 completed
# ticker='OSH'
# [*********************100%***********************]  1 of 1 completed
# ticker='UDMY'
# [*********************100%***********************]  1 of 1 completed
# ticker='ZIP'
# [*********************100%***********************]  1 of 1 completed
# ticker='WMT'
# [*********************100%***********************]  1 of 1 completed
# ticker='SPSC'
# [*********************100%***********************]  1 of 1 completed
# ticker='TWLO'
# [*********************100%***********************]  1 of 1 completed
# ticker='PCOR'
# [*********************100%***********************]  1 of 1 completed
# ticker='INTA'
# [*********************100%***********************]  1 of 1 completed
# ticker='DNA'
# [*********************100%***********************]  1 of 1 completed
# ticker='TRV'
# [*********************100%***********************]  1 of 1 completed
# ticker='ENOV'
# [*********************100%***********************]  1 of 1 completed
# ticker='BE'
# [*********************100%***********************]  1 of 1 completed
# ticker='RBLX'
# [*********************100%***********************]  1 of 1 completed
# ticker='PTON'
# [*********************100%***********************]  1 of 1 completed
# ticker='MTH'
# [*********************100%***********************]  1 of 1 completed
# 155   PTON  2023-02-21   S - Sale       -54530               3     13.250000
# 158    MTH  2023-02-22   S - Sale       -68153               5    107.349998
# 159     AN  2023-02-21   S - Sale       -50066               3    143.380005
#
#      Actual Price  Increase/Decrease Pct
# 0       58.314999                 -10.93
# 2      474.230011                  -0.85
# 14      42.305000                  -7.91
# 15      97.910004                  -2.90
# 17      55.139999                   0.88
# 24      88.584999                  -3.51
# 29      33.680000                  -5.31
# 37      83.730003                   3.32
# 48      54.139999                  -2.78
# 49      50.759998                  -1.42
# 50      50.759998                  -1.44
# 51      29.620001                 -16.56
# 54      30.170000                 -11.26
# 55      28.091999                  -5.22
# 56     111.739998                  -5.05
# 57     137.854996                  -2.53
# 58      10.630000                  -6.34
# 60     101.605003                  -2.59
# 64      33.730000                 -12.59
# 66     164.500000                  -1.81
# 69      73.000000                  -3.00
# 71      19.370001                  -7.76
# 75     119.410004                   0.73
# 83      41.830002                  -3.91
# 84     204.880005                 -16.90
# 87     275.910004                  -6.90
# 92     295.510010                   2.82
# 99      99.430000                  -4.93
# 105      3.945000                 -16.95
# 109     34.959999                  -1.35
# 115      9.285000                  -7.80
# 118     15.290000                 -13.27
# 127    137.880005                  -4.41
# 128    143.279999                  -2.30
# 129     64.352501                  -0.83
# 130     58.349998                 -10.52
# 131     38.924999                   2.81
# 134      1.385000                 -17.56
# 138    175.350006                  -5.46
# 142     53.990002                 -12.31
# 149     20.260000                  -9.63
# 153     41.279999                   9.90
# 155     11.595000                 -12.49
# 158    107.449997                   0.09
# 159    133.869995                  -6.63

# %%
def omg_back_test(df):
    winning_long = len(df[(df['Increase/Decrease Pct'] > 0) & (df['Total Volume'] > 0)])
    loosing_long = len(df[(df['Increase/Decrease Pct'] < 0) & (df['Total Volume'] > 0)])
    winning_short = len(df[(df['Increase/Decrease Pct'] < 0) & (df['Total Volume'] < 0)])
    loosing_short = len(df[(df['Increase/Decrease Pct'] > 0) & (df['Total Volume'] < 0)])
    
    # Print the number of rows with positive and negative increase pct
    print(f"{winning_long=}")
    print(f"{loosing_long=}")
    print(f"{winning_short=}")
    print(f"{loosing_short=}")
# Out:
# winning_long=0
# loosing_long=0
# winning_short=38
# loosing_short=7

# %%
omg_back_test(priced_df)

# %%
stock_test = yf.download("MTH", start="2023-02-22", end=get_today())
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_test.iloc[-1]['Close']
# Out:
# 106.48999786376953

# %%
stock_test.loc['Date']("2023-03-01")
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "pandas\_libs\tslibs\parsing.pyx", line 440, in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso
#   File "pandas\_libs\tslibs\parsing.pyx", line 649, in pandas._libs.tslibs.parsing.dateutil_parse
# ValueError: Unknown datetime string format, unable to parse: Date
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\datetimes.py", line 704, in get_loc
#     parsed, reso = self._parse_with_reso(key)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\datetimelike.py", line 230, in _parse_with_reso
#     parsed, reso_str = parsing.parse_time_string(label, freq)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "pandas\_libs\tslibs\parsing.pyx", line 367, in pandas._libs.tslibs.parsing.parse_time_string
#   File "pandas\_libs\tslibs\parsing.pyx", line 445, in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso
# pandas._libs.tslibs.parsing.DateParseError: Unknown datetime string format, unable to parse: Date
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Curtis\AppData\Local\Temp\ipykernel_8376\2133603813.py", line 1, in <module>
#     stock_test.loc['Date']("2023-03-01")
#     ~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py", line 1073, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py", line 1312, in _getitem_axis
#     return self._get_label(key, axis=axis)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py", line 1260, in _get_label
#     return self.obj.xs(label, axis=axis)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py", line 4056, in xs
#     loc = index.get_loc(key)
#           ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\datetimes.py", line 706, in get_loc
#     raise KeyError(key) from err
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 1288, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 1177, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 1049, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 935, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 1003, in get_records
#     lines, first = inspect.getsourcelines(etb.tb_frame)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\inspect.py", line 1244, in getsourcelines
#     lines, lnum = findsource(object)
#                   ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Curtis\AppData\Local\Programs\Python\Python311\Lib\inspect.py", line 1081, in findsource
#     raise OSError('could not get source code')
# OSError: could not get source code

# %%
stock_test.loc(pd.to_datetime('2023-02-24', format='%Y-%m-%d'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: Timestamp('2023-02-24 00:00:00')
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 stock_test.loc(pd.to_datetime('2023-02-24', format='%Y-%m-%d'))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:668, in _LocationIndexer.__call__(self, axis)
#     665 new_self = type(self)(self.name, self.obj)
#     667 if axis is not None:
# --> 668     axis = self.obj._get_axis_number(axis)
#     669 new_self.axis = axis
#     670 return new_self
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:556, in NDFrame._get_axis_number(cls, axis)
#     554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
# --> 556     raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named 2023-02-24 00:00:00 for object type DataFrame

# %%
stock_test.index[2] ==
# Out:
# True

# %%
pd.to_datetime('2023-02-22', format='%Y-%m-%d')
# Out:
# Timestamp('2023-02-22 00:00:00')

# %%
stock_test
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2023-02-22  107.720001  108.169998  105.879997  107.349998  107.349998  662100
# 2023-02-23  108.000000  109.260002  106.550003  108.690002  108.690002  279300
# 2023-02-24  105.790001  108.059998  104.629997  107.599998  107.599998  403700
# 2023-02-27  109.160004  109.489998  107.110001  108.480003  108.480003  315200
# 2023-02-28  108.110001  109.980003  108.110001  109.230003  109.230003  356100
# 2023-03-01  108.519997  110.040001  107.639999  108.239998  108.239998  397900
# 2023-03-02  106.949997  107.599998  105.160004  107.309998  107.309998  422500
# 2023-03-03  108.919998  111.010002  107.230003  109.980003  109.980003  345900
# 2023-03-06  112.260002  112.260002  108.849998  109.260002  109.260002  568500
# 2023-03-07  110.010002  110.300003  107.529999  107.559998  107.559998  302100
# 2023-03-08  108.510002  110.449997  107.000000  110.430000  110.430000  264500
# 2023-03-09  110.500000  112.459999  109.080002  109.110001  109.110001  310800
# 2023-03-10  110.949997  110.949997  104.930000  106.489998  106.489998  514800
